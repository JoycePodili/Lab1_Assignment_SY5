# %% [markdown]
# <a href="https://colab.research.google.com/github/JoycePodili/Lab1_Assignment_SY5/blob/main/DELV_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "Name": [
        "Amit", "Priya", "Rahul", "Sneha", "Amit",
        "Neha", "Rohan", "Priya", "Kiran", "Anjali",
        "Vikas", "Meena", "Rahul", "Suresh", "Pooja",
        "Anjali", "Kunal", "Meena", "Riya", "Arjun"
    ],
    "Roll_No": [
        101,102,103,104,105,
        106,107,108,109,110,
        111,112,113,114,115,
        116,117,118,119,120
    ],
    "Age": [
        20,19,21,20,20,
        19,22,19,21,20,
        22,21,21,20,19,
        20,22,21,19,20
    ]
}

# %%
students = pd.DataFrame(data)

# %%
print(students)
# Out:
#       Name  Roll_No  Age
# 0     Amit      101   20
# 1    Priya      102   19
# 2    Rahul      103   21
# 3    Sneha      104   20
# 4     Amit      105   20
# 5     Neha      106   19
# 6    Rohan      107   22
# 7    Priya      108   19
# 8    Kiran      109   21
# 9   Anjali      110   20
# 10   Vikas      111   22
# 11   Meena      112   21
# 12   Rahul      113   21
# 13  Suresh      114   20
# 14   Pooja      115   19
# 15  Anjali      116   20
# 16   Kunal      117   22
# 17   Meena      118   21
# 18    Riya      119   19
# 19   Arjun      120   20

# %%
duplicates = students[students.duplicated(subset=["Name"])]
print(duplicates)
# Out:
#       Name  Roll_No  Age
# 4     Amit      105   20
# 7    Priya      108   19
# 12   Rahul      113   21
# 15  Anjali      116   20
# 17   Meena      118   21
